# %%
import pydicom

ds = pydicom.dcmread(r"C:\Users\gcpup\Downloads\00073745e02e69432c002b527c565151.dicom")

print("View Position:", ds.get("ViewPosition"))
print("Series Description:", ds.get("SeriesDescription"))
print("Protocol Name:", ds.get("ProtocolName"))
print("Body Part:", ds.get("BodyPartExamined"))
# Out:
# View Position: None
# Series Description: None
# Protocol Name: None
# Body Part: None
