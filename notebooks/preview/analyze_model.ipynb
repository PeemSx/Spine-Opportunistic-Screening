# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path = r"C:\Users\gcpup\Desktop\Workspaces\AI\Spine-Opportunistic-Screening\outputs\hrnet18_no_buu\train_log.csv"

df = pd.read_csv(csv_path)

plt.figure(figsize=(8, 5))
plt.plot(df["epoch"], df["train_loss"], label="Train Loss")
plt.plot(df["epoch"], df["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
print(f"Lowest Loss: {df['val_loss'].min()} at epoch {df['val_loss'].idxmin()}")
# Out:
# Lowest Loss: 0.8246284302543191 at epoch 28
